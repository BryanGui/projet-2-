# %% [markdown]
# # <font color=green>PROJET 2</font>

# %% [markdown]
# ## <font color=green>CLEANING DATA</font>

# %%
# %%HTML
# <p Téléchargement de la DB sur les données nutritionnelles /p>
# Out:
# <p Téléchargement de la DB sur les données nutritionnelles /p>

# %%
import pandas as pd

# %%
df = pd.read_csv('products.csv', sep='\t', low_memory = False)

# %%
# %%HTML
# <p On regarde la dimension de la DB /p>
# Out:
# <p On regarde la dimension de la DB /p>

# %%
df.shape
# Out:
# (320772, 162)

# %%
# %%HTML
# <p On regarde la l intitulé de chaque colonne /p>
# Out:
# <p On regarde la l intitulé de chaque colonne /p>

# %%
for x in df:
    print(x)
# Out:
# code
# url
# creator
# created_t
# created_datetime
# last_modified_t
# last_modified_datetime
# product_name
# generic_name
# quantity
# packaging
# packaging_tags
# brands
# brands_tags
# categories
# categories_tags
# categories_fr
# origins
# origins_tags
# manufacturing_places
# manufacturing_places_tags
# labels
# labels_tags
# labels_fr
# emb_codes
# emb_codes_tags
# first_packaging_code_geo
# cities
# cities_tags
# purchase_places
# stores
# countries
# countries_tags
# countries_fr
# ingredients_text
# allergens
# allergens_fr
# traces
# traces_tags
# traces_fr
# serving_size
# no_nutriments
# additives_n
# additives
# additives_tags
# additives_fr
# ingredients_from_palm_oil_n
# ingredients_from_palm_oil
# ingredients_from_palm_oil_tags
# ingredients_that_may_be_from_palm_oil_n
# ingredients_that_may_be_from_palm_oil
# ingredients_that_may_be_from_palm_oil_tags
# nutrition_grade_uk
# nutrition_grade_fr
# pnns_groups_1
# pnns_groups_2
# states
# states_tags
# states_fr
# ...

# %%
# %%HTML
# <p On regarde le type de données /p>
# Out:
# <p On regarde le type de données /p>

# %%
df.dtypes
# Out:
# code                                 object
# url                                  object
# creator                              object
# created_t                            object
# created_datetime                     object
# last_modified_t                      object
# last_modified_datetime               object
# product_name                         object
# generic_name                         object
# quantity                             object
# packaging                            object
# packaging_tags                       object
# brands                               object
# brands_tags                          object
# categories                           object
# categories_tags                      object
# categories_fr                        object
# origins                              object
# origins_tags                         object
# manufacturing_places                 object
# manufacturing_places_tags            object
# ...

# %%
# %%HTML
# <p Il y a deux types de variables, on va creer deux base de données:/p>
#         <p -df_float pour les données float /p>
#         <p -df_object pour les données str /p>
# Out:
# <p Il y a deux types de variables, on va creer deux base de données:/p>
#         <p -df_float pour les données float /p>
#         <p -df_object pour les données str /p>

# %% [markdown]
# ### Données de types objects

# %%
df_float = df.select_dtypes(exclude=['object'])

# %%
df_float.shape
# Out:
# (320772, 106)

# %%
# %%HTML
# <p Il y a 106 colonnes avec des données de type float /p>
# Out:
# <p Il y a 106 colonnes avec des données de type float /p>

# %%
for x in df_float:
    print(x)
# Out:
# no_nutriments
# additives_n
# ingredients_from_palm_oil_n
# ingredients_from_palm_oil
# ingredients_that_may_be_from_palm_oil_n
# ingredients_that_may_be_from_palm_oil
# nutrition_grade_uk
# energy_100g
# energy-from-fat_100g
# fat_100g
# saturated-fat_100g
# butyric-acid_100g
# caproic-acid_100g
# caprylic-acid_100g
# capric-acid_100g
# lauric-acid_100g
# myristic-acid_100g
# palmitic-acid_100g
# stearic-acid_100g
# arachidic-acid_100g
# behenic-acid_100g
# lignoceric-acid_100g
# cerotic-acid_100g
# montanic-acid_100g
# melissic-acid_100g
# monounsaturated-fat_100g
# polyunsaturated-fat_100g
# omega-3-fat_100g
# alpha-linolenic-acid_100g
# eicosapentaenoic-acid_100g
# docosahexaenoic-acid_100g
# omega-6-fat_100g
# linoleic-acid_100g
# arachidonic-acid_100g
# gamma-linolenic-acid_100g
# dihomo-gamma-linolenic-acid_100g
# omega-9-fat_100g
# oleic-acid_100g
# elaidic-acid_100g
# gondoic-acid_100g
# mead-acid_100g
# erucic-acid_100g
# nervonic-acid_100g
# trans-fat_100g
# ...

# %%
# %%HTML
# <p On fait une analyse sur les données /p>
# Out:
# <p On fait une analyse sur les données /p>

# %%
print(df_float.describe(include ='all'))
# Out:
#        no_nutriments    additives_n  ingredients_from_palm_oil_n  \
# count              0  248939.000000                248939.000000
# mean             NaN       1.936024                     0.019659
# std              NaN       2.502019                     0.140524
# min              NaN       0.000000                     0.000000
# 25%              NaN       0.000000                     0.000000
# 50%              NaN       1.000000                     0.000000
# 75%              NaN       3.000000                     0.000000
# max              NaN      31.000000                     2.000000
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                          0                            248939.000000
# mean                         NaN                                 0.055246
# std                          NaN                                 0.269207
# min                          NaN                                 0.000000
# ...

# %%
# %%HTML
# <p On regarde les colonnes ou il ny a pas de données /p>
# Out:
# <p On regarde les colonnes ou il ny a pas de données /p>

# %%
for i in range(107):
    x = df_float.iloc[:,i:i+1].count()
    if x.all() == False:
        print(x)
        print(i)
# Out:
# no_nutriments    0
# dtype: int64
# 0
# ingredients_from_palm_oil    0
# dtype: int64
# 3
# ingredients_that_may_be_from_palm_oil    0
# dtype: int64
# 5
# nutrition_grade_uk    0
# dtype: int64
# 6
# butyric-acid_100g    0
# dtype: int64
# 11
# caproic-acid_100g    0
# dtype: int64
# 12
# lignoceric-acid_100g    0
# dtype: int64
# 21
# cerotic-acid_100g    0
# dtype: int64
# 22
# melissic-acid_100g    0
# dtype: int64
# 24
# elaidic-acid_100g    0
# dtype: int64
# 38
# mead-acid_100g    0
# dtype: int64
# 40
# erucic-acid_100g    0
# dtype: int64
# 41
# nervonic-acid_100g    0
# dtype: int64
# 42
# chlorophyl_100g    0
# dtype: int64
# 100
# glycemic-index_100g    0
# dtype: int64
# 104
# water-hardness_100g    0
# dtype: int64
# 105

# %%
# %%HTML
# <p On supprime les colonnes /p>
# Out:
# <p On supprime les colonnes /p>

# %%
df_float = df_float.drop(df_float.columns[[0,3,5,6,11,12,21,22,24,38,40,41,42,100,104,105]], axis =1)

# %%
df_float.shape
# Out:
# (320772, 90)

# %%
for x in df_float:
    print(x)
# Out:
# additives_n
# ingredients_from_palm_oil_n
# ingredients_that_may_be_from_palm_oil_n
# energy_100g
# energy-from-fat_100g
# fat_100g
# saturated-fat_100g
# caprylic-acid_100g
# capric-acid_100g
# lauric-acid_100g
# myristic-acid_100g
# palmitic-acid_100g
# stearic-acid_100g
# arachidic-acid_100g
# behenic-acid_100g
# montanic-acid_100g
# monounsaturated-fat_100g
# polyunsaturated-fat_100g
# omega-3-fat_100g
# alpha-linolenic-acid_100g
# eicosapentaenoic-acid_100g
# docosahexaenoic-acid_100g
# omega-6-fat_100g
# linoleic-acid_100g
# arachidonic-acid_100g
# gamma-linolenic-acid_100g
# dihomo-gamma-linolenic-acid_100g
# omega-9-fat_100g
# oleic-acid_100g
# gondoic-acid_100g
# trans-fat_100g
# cholesterol_100g
# carbohydrates_100g
# sugars_100g
# sucrose_100g
# glucose_100g
# fructose_100g
# lactose_100g
# maltose_100g
# maltodextrins_100g
# starch_100g
# polyols_100g
# fiber_100g
# proteins_100g
# casein_100g
# serum-proteins_100g
# nucleotides_100g
# salt_100g
# sodium_100g
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use('ggplot')

# %%
s = df_float['additives_n']

# %%
s.describe()
# Out:
# count    248939.000000
# mean          1.936024
# std           2.502019
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max          31.000000
# Name: additives_n, dtype: float64

# %%
#Boolean indexing
df_float[df_float['additives_n'] < 0]
# Out:
# Empty DataFrame
# ...

# %%
#Cursory plot
plt.figure(figsize = (15, 5))
plt.plot(df_float['additives_n'])
plt.show()

# %%
plt.figure(figsize = (15,5))
plt.scatter(x= df_float['additives_n'].index, y = df_float['additives_n'])
plt.show()

# %%
plt.figure()
df_float['additives_n'].diff().hist()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure()
df_float['additives_n'].hist(color='k', alpha=0.5, bins=1)
plt.show()

# %%
df_float.iloc[1]
# Out:
# additives_n                                   0.00000
# ingredients_from_palm_oil_n                   0.00000
# ingredients_that_may_be_from_palm_oil_n       0.00000
# energy_100g                                2243.00000
# energy-from-fat_100g                              NaN
# fat_100g                                     28.57000
# saturated-fat_100g                           28.57000
# caprylic-acid_100g                                NaN
# capric-acid_100g                                  NaN
# lauric-acid_100g                                  NaN
# myristic-acid_100g                                NaN
# palmitic-acid_100g                                NaN
# stearic-acid_100g                                 NaN
# arachidic-acid_100g                               NaN
# behenic-acid_100g                                 NaN
# montanic-acid_100g                                NaN
# monounsaturated-fat_100g                          NaN
# ...

# %%
df_float['ingredients_from_palm_oil_n'].describe()
# Out:
# count    248939.000000
# mean          0.019659
# std           0.140524
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           2.000000
# Name: ingredients_from_palm_oil_n, dtype: float64

# %%
df_float[df_float['ingredients_from_palm_oil_n'] > 3]
# Out:
# Empty DataFrame
# ...

# %%
df_float['ingredients_that_may_be_from_palm_oil_n'].describe()
# Out:
# count    248939.000000
# mean          0.055246
# std           0.269207
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           6.000000
# Name: ingredients_that_may_be_from_palm_oil_n, dtype: float64

# %%
df_float['energy_100g'].describe()
# Out:
# count     261113.000000
# mean        1141.914605
# std         6447.154093
# min            0.000000
# 25%          377.000000
# 50%         1100.000000
# 75%         1674.000000
# max      3251373.000000
# Name: energy_100g, dtype: float64

# %%
df_float[df_float['energy_100g'] > 20000]
# Out:
#         additives_n  ingredients_from_palm_oil_n  \
# 112681            0                            0
# 119184            1                            0
# 153704            1                            0
# 176697          NaN                          NaN
# 212928            0                            0
# 219302          NaN                          NaN
# 249101          NaN                          NaN
# 313506            1                            0
# 317171          NaN                          NaN
#
#         ingredients_that_may_be_from_palm_oil_n  energy_100g  \
# 112681                                        0       110579
# 119184                                        0        94140
# 153704                                        0        26861
# 176697                                      NaN        22000
# 212928                                        0      3251373
# 219302                                      NaN        69292
# ...

# %%
#supression de la ligne 212 928 valeurs est excessive et pas de nutrition-score calculé.
#remplacement de la valeur par la moyenne
df_float.loc[df_float['energy_100g'] == 3251373,'energy_100g'] = 1141

# %%
df_float['energy_100g'].describe()
# Out:
# count    261113.000000
# mean       1129.466998
# std        1052.567467
# min           0.000000
# 25%         377.000000
# 50%        1100.000000
# 75%        1674.000000
# max      231199.000000
# Name: energy_100g, dtype: float64

# %%
df_float['energy-from-fat_100g'].describe()
# Out:
# count     857.000000
# mean      585.501214
# std       712.809943
# min         0.000000
# 25%        49.400000
# 50%       300.000000
# 75%       898.000000
# max      3830.000000
# Name: energy-from-fat_100g, dtype: float64

# %%
df_float['fat_100g'].describe()
# Out:
# count    243891.000000
# mean         12.730379
# std          17.578747
# min           0.000000
# 25%           0.000000
# 50%           5.000000
# 75%          20.000000
# max         714.290000
# Name: fat_100g, dtype: float64

# %%
df_float[df_float['fat_100g'] > 100]
# Out:
#         additives_n  ingredients_from_palm_oil_n  \
# 112681            0                            0
# 245311            7                            1
# 303101          NaN                          NaN
# 305054          NaN                          NaN
#
#         ingredients_that_may_be_from_palm_oil_n  energy_100g  \
# 112681                                        0       110579
# 245311                                        0        18700
# 303101                                      NaN         3737
# 305054                                      NaN         1482
#
#         energy-from-fat_100g  fat_100g  saturated-fat_100g  \
# 112681                   NaN    714.29               100.0
# 245311                   NaN    380.00               210.0
# 303101                   NaN    101.00                15.0
# 305054                   NaN    105.00                 0.3
#
#         caprylic-acid_100g  capric-acid_100g  lauric-acid_100g  \
# ...

# %%
df_float['saturated-fat_100g'].describe()
# Out:
# count    229554.000000
# mean          5.129932
# std           8.014238
# min           0.000000
# 25%           0.000000
# 50%           1.790000
# 75%           7.140000
# max         550.000000
# Name: saturated-fat_100g, dtype: float64

# %%
df_float[df_float['saturated-fat_100g'] > 100]
# Out:
#         additives_n  ingredients_from_palm_oil_n  \
# 119389            0                            0
# 245311            7                            1
# 313506            1                            0
#
#         ingredients_that_may_be_from_palm_oil_n  energy_100g  \
# 119389                                        0         8523
# 245311                                        0        18700
# 313506                                        0       231199
#
#         energy-from-fat_100g  fat_100g  saturated-fat_100g  \
# 119389                   NaN       NaN              175.38
# 245311                   NaN       380              210.00
# 313506                   NaN       NaN              550.00
#
#         caprylic-acid_100g  capric-acid_100g  lauric-acid_100g  \
# 119389                 NaN               NaN               NaN
# 245311                 NaN               NaN               NaN
# 313506                 NaN               NaN               NaN
#
# ...

# %%
#saturated-fat est une composante du fat il est donc impossible fat_100g < saturated-fat_100g
#on va chercher les lignes ou saturated-fat > fat
print((df_float['saturated-fat_100g'] > df_float['fat_100g']).value_counts())
# Out:
# False    320418
# True        354
# dtype: int64

# %%
print(df_float.loc[df_float['saturated-fat_100g']==df_float['fat_100g'],:])
# Out:
#         additives_n  ingredients_from_palm_oil_n  \
# 1                 0                            0
# 146               0                            0
# 147               1                            0
# 148               0                            0
# 173               0                            0
# 207               3                            0
# 226               2                            0
# 240               3                            0
# 282               0                            0
# 331               0                            0
# 332               0                            0
# 333               0                            0
# 334               0                            0
# 335               0                            0
# 336               0                            0
# 337               0                            0
# 338               0                            0
# 343               0                            0
# ...

# %%
df_float.loc[:,['saturated-fat_100g','fat_100g']].head(5)
# Out:
#    saturated-fat_100g  fat_100g
# 0                 NaN       NaN
# 1               28.57     28.57
# 2                0.00     17.86
# 3                5.36     57.14
# 4                 NaN      1.43

# %%
print(df_float.loc[:,['saturated-fat_100g','fat_100g'] df_float['saturated-fat_100g']== df_float['fat_100g'])
# Out:
#   File "<ipython-input-105-f8cdce5acc37>", line 1
#     print(df_float.loc[:,['saturated-fat_100g','fat_100g'] df_float['saturated-fat_100g']==df_float['fat_100g'])
#                                                                   ^
# SyntaxError: invalid syntax
